# %% [markdown]
# # **Установка Ultralytics**

# %%
# Install Ultralytics
# !pip install ultralytics

# %% [markdown]
# # **Монтирование google-диска в проект**

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

ROOT_DIR = '/content/gdrive/My Drive/Colab Notebooks/SkyVision'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ❌# **Перевод модели из формата** *.h5* **в** *.pt*

# %%
# !pip install onnxruntime
# !pip install git+https://github.com/onnx/tensorflow-onnx
# !pip install tensorflow torch

# %%
# !python3 -m tf2onnx.convert --saved-model /content/tmp_model --output "model.onnx"

# %%
# !pip install onnx2torch

# %% [markdown]
# # **Удаление текущей модели (если нужно)**

# %%
import shutil
shutil.rmtree("runs")
#shutil.rmtree("/content/gdrive/My Drive/Colab Notebooks/SkyVision/runs")

# %% [markdown]
# # **Подключение модулей ultralytics и os**

# %%
import os
from ultralytics import YOLO

# %% [markdown]
# # **Загрузка модели YOLOv8**

# %% [markdown]
# ### **Загрузка предобученной модели YOLOv8m-obb**

# %%
# Loading a pre-trained model YOLOv8m-obb
model = YOLO("yolov8l.pt")
# Out:
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 236MB/s]

# %% [markdown]
# ### **Обучение предобученной модели YOLOv8m-obb**

# %%
# Train model
results = model.train(data=os.path.join(ROOT_DIR, 'Building Detection From Satellite Images.v11i.yolov8-obb/data.yaml'), epochs=20, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### **Сохрание результата обучения на google-диск**

# %%
import locale
print(locale.getpreferredencoding())

def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# Copy results
# !scp -r /content/runs '/content/gdrive/My Drive/Colab Notebooks/SkyVision'

# %% [markdown]
# # **Работа с готовой (обученной) моделью**

# %% [markdown]
# ### **Подключение необходимых модулей**

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import torch

# %% [markdown]
# ### **Подготовка нейросети**

# %%
model = YOLO('/content/gdrive/My Drive/Colab Notebooks/SkyVision/runs/detect/train/weights/best.pt')

# %% [markdown]
# ### **Подготовка изображения для распознования**

# %%
img = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/SkyVision/sweet_home.png')
print(img.shape)

results = model(img, imgsz=640, iou=0.4, conf=0.4, verbose=True)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# (702, 767, 3)
#
# 0: 608x640 (no detections), 102.8ms
# Speed: 3.8ms preprocess, 102.8ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)

# %% [markdown]
# ### **Распознование объектов на изображении и вывод результатов**

# %%
annotated_frame = results[0].plot()
annotated_frame = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)
plt.imshow(annotated_frame)
plt.show()
